# %%
# !git clone https://github.com/Kartikaya-git/Breast-cancer-classification
# %cd Breast-cancer-classification
# !python breast_cancer_knn1.py
# Out:
# Data shape: (569, 30) Labels shape: (569,)
# Class distribution: [212 357]
