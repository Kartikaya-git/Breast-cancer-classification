# %%
# !git pull
# !python breast_cancer_knn1.py
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 1), reused 4 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.27 KiB | 1.27 MiB/s, done.
# From https://github.com/Kartikaya-git/Breast-cancer-classification
#    0e6a3a5..7af267e  main       -> origin/main
# Updating 0e6a3a5..7af267e
# Fast-forward
#  breast_cancer_knn1.py | 44 ++++++++++++++++++++++++++++++++++++++++++--
#  tester.ipynb          | 10 +++++-----
#  2 files changed, 47 insertions(+), 7 deletions(-)
# K = 5
# Train time        : 0.001164 s
# Predict time      : 0.055314 s
# Predict time/prob.: 0.001788 s
# Per-sample latency: 0.4852 ms (114 samples)
